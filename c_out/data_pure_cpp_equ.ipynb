# %% [markdown]
# by nt.cpp
#
# ```cpp
# Cubic default_z_flow(double vz0=10, int para_n_ptcs=1e5, double para_cell_l=2, int para_cubic_size=50, int para_box_size=5, double para_r=1, double para_m=1e-26, double para_T0=300) {
#     return Cubic(para_n_ptcs, para_cell_l, para_cubic_size, para_box_size, para_r, para_m, para_T0, false, generate_z_flow(vz0));
# }
# ```
#
# ```shell
# cubic=default_z_flow()
# nσ^3 = 0.8
# cubic.run(1000,1e-9,false,true,1,false,true)
# Simulation[====================================================================================================] 100% [09m:24s<00m:00s] 1000/1000
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('particle_records_tensor_equ.csv', header=None, names=['t', 'i', 'j', 'k', 'ux', 'uy', 'uz', 'pk_xx', 'pk_xy', 'pk_xz', 'pk_yx', 'pk_yy', 'pk_yz', 'pk_zx', 'pk_zy', 'pk_zz', 'qk_x', 'qk_y', 'qk_z'])
mean = data.groupby('t').mean()

# %%
data
# Out:
#                    t  i  j  k         ux          uy         uz         pk_xx  \
# 0       1.000000e-09  0  0  0 -1332060.0  -803167.00 -3919510.0  4.102440e+11
# 1       1.000000e-09  0  0  1 -4902660.0  2545420.00 -2034860.0  5.175950e+11
# 2       1.000000e-09  0  0  2   251667.0 -2991310.00  -892267.0  3.756030e+11
# 3       1.000000e-09  0  0  3 -1626950.0 -1831260.00  1944840.0  3.265340e+11
# 4       1.000000e-09  0  0  4  -679778.0  -672630.00   676310.0  3.967430e+11
# ...              ... .. .. ..        ...         ...        ...           ...
# 999995  1.000000e-06  9  9  5  -353726.0   917824.00  -126996.0  3.704740e+11
# 999996  1.000000e-06  9  9  6  2595900.0 -1510080.00 -3088310.0  3.749370e+11
# 999997  1.000000e-06  9  9  7  2742710.0    -5513.08  2108220.0  4.084790e+11
# 999998  1.000000e-06  9  9  8  1333120.0  1116090.00  2996310.0  3.419770e+11
# 999999  1.000000e-06  9  9  9 -3673880.0   761760.00 -3190980.0  3.788400e+11
#
#                pk_xy         pk_xz         pk_yx         pk_yy         pk_yz  \
# 0      -1.385800e+10  6.226190e+09 -1.385800e+10  4.192740e+11  6.984900e+10
# 1       5.038420e+10 -3.486280e+09  5.038420e+10  4.045550e+11  2.765910e+10
# 2      -5.455110e+10 -4.176910e+10 -5.455110e+10  4.529640e+11  4.202040e+09
# 3       2.829040e+10  1.121450e+10  2.829040e+10  4.760650e+11  5.431060e+10
# 4       1.484230e+10 -2.518690e+09  1.484230e+10  3.617900e+11 -2.877630e+10
# ...              ...           ...           ...           ...           ...
# 999995 -4.342920e+10  9.283600e+10 -4.342920e+10  4.374980e+11  4.017640e+10
# 999996 -3.699090e+10  7.170290e+10 -3.699090e+10  3.045700e+11 -8.937980e+09
# 999997 -6.355950e+10 -4.971630e+10 -6.355950e+10  4.290580e+11 -4.698060e+10
# 999998 -4.356180e+10 -3.550220e+10 -4.356180e+10  4.469790e+11 -5.597020e+10
# 999999 -9.253180e+09  3.067080e+10 -9.253180e+09  4.927650e+11 -2.212810e+10
#
#                pk_zx         pk_zy         pk_zz          qk_x          qk_y  \
# 0       6.226190e+09  6.984900e+10  3.751370e+11  9.237240e+17 -1.427520e+18
# 1      -3.486280e+09  2.765910e+10  3.687180e+11  2.783610e+18 -3.463340e+18
# 2      -4.176910e+10  4.202040e+09  3.637220e+11 -4.089420e+17 -3.620830e+18
# 3       1.121450e+10  5.431060e+10  4.506810e+11  1.791400e+18 -9.101130e+18
# 4      -2.518690e+09 -2.877630e+10  3.678080e+11  7.593360e+17  3.432490e+18
# 9.980000e-07  4.122085e+11 -6.307157e+08 -1.869868e+09 -6.307157e+08
# 9.990000e-07  4.121514e+11 -6.637685e+08 -1.804719e+09 -6.637685e+08
# 1.000000e-06  4.120814e+11 -6.791253e+08 -1.745384e+09 -6.791253e+08
#
#                      pk_zz          qk_x          qk_y          qk_z
# t
# 1.000000e-09  4.114344e+11  3.460914e+16  2.071701e+15  1.619600e+17
# 2.000000e-09  4.114687e+11  3.328386e+16  8.592156e+15  1.609925e+17
# 3.000000e-09  4.115455e+11  2.960067e+16  1.661117e+15  1.623898e+17
# 4.000000e-09  4.115410e+11  3.213989e+16  5.494260e+15  1.621184e+17
# 5.000000e-09  4.116111e+11  3.686358e+16  6.368228e+15  1.634416e+17
# ...                    ...           ...           ...           ...
# 9.960000e-07  4.117411e+11  7.601542e+15  1.654381e+16  1.809477e+17
# 9.970000e-07  4.117421e+11  1.183957e+16  1.545016e+16  1.813193e+17
# 9.980000e-07  4.117517e+11  1.157446e+16  1.518230e+16  1.840463e+17
# 9.990000e-07  4.117894e+11  9.616467e+15  1.488955e+16  1.838724e+17
# 1.000000e-06  4.117577e+11  5.539166e+15  1.537294e+16  1.778814e+17
#
# [1000 rows x 18 columns]

# %%
fig, ax1 = plt.subplots()
ax1.plot(mean.index, mean['ux'], 'g', label='$u_x$')
ax1.plot(mean.index, mean['uy'], 'b', label='$u_y$')
# ax2 = ax1.twinx()
ax1.plot(mean.index, mean['uz'], 'r', label='$u_z$')
# ax1.legend(loc='upper left')
ax1.legend()

# %%
fig, ax1 = plt.subplots()
ax1.plot(mean.index, mean['pk_xz'], 'g', label='$p^k_{xz}$')
ax1.plot(mean.index, mean['pk_yz'], 'b', label='$p^k_{yz}$')
# ax1.plot(mean.index, mean['pk_zx'], label='$p^k_{zx}$')
# ax1.plot(mean.index, mean['pk_zy'], label='$p^k_{zy}$')
ax1.legend(loc='upper left')
# ax2 = ax1.twinx()
ax1.plot(mean.index, mean['pk_xy'], 'r', label='$p^k_{xy}$')
# ax2.plot(mean.index, mean['pk_yx'], label='$p^k_{yx}$')
ax1.legend()

# %%
fig, ax1 = plt.subplots()
ax1.plot(mean.index, mean['pk_xx'], 'g', label='$p^k_{xx}$')
ax1.plot(mean.index, mean['pk_yy'], 'b', label='$p^k_{yy}$')
# ax2 = ax1.twinx()
ax1.plot(mean.index, mean['pk_zz'], 'r', label='$p^k_{zz}$')
# ax1.legend(loc='upper left', framealpha=0.5)
# ax2.legend(loc='upper right', framealpha=0.8)
ax1.legend()

# %%
fig, ax1 = plt.subplots()
ax1.plot(mean.index, mean['qk_x'], 'g', label='$q^k_x$')
ax1.plot(mean.index, mean['qk_y'], 'b', label='$q^k_y$')
# ax2 = ax1.twinx()
ax1.plot(mean.index, mean['qk_z'], 'r', label='$q^k_z$')
# ax1.legend(loc='upper left')
# ax2.legend(loc='upper right')
ax1.legend()

# %%
Ts = pd.read_csv('particle_records_Ts_equ.csv', header=None)
fig, ax1 = plt.subplots()
ax1.plot(Ts[0], Ts[1], label='$T$')
ax2 = ax1.twinx()
plt.xlabel('time (s)')
plt.ylabel('temperature (K)')
# linear regression using numpy
A = np.vstack([Ts[0], np.ones(len(Ts[0]))]).T
m, c = np.linalg.lstsq(A, Ts[1], rcond=None)[0]
ax2.plot(Ts[0], Ts[1]-m*Ts[0]-c, 'r', label='$T - T_{lin fit}$')
# plt.ylim(Ts[1].min(), Ts[1].max())
ax1.legend()
ax2.legend()

# %%
acceptances = pd.read_csv('particle_records_accepts_equ.csv', header=None)
plt.plot(acceptances[0], acceptances[1] / 100000, label='Heaviside rate')
plt.plot(acceptances[0], acceptances[2] / 100000, label='acceptance rate')
plt.plot(acceptances[0], acceptances[2] / acceptances[1], label='accepted after Heaviside')
plt.legend()
