# %% [markdown]
# by nt.cpp
#
# ```cpp
# Cubic default_z_flow(double vz0=10, int para_n_ptcs=1e5, double para_cell_l=2, int para_cubic_size=50, int para_box_size=5, double para_r=1, double para_m=1e-26, double para_T0=300) {
#     return Cubic(para_n_ptcs, para_cell_l, para_cubic_size, para_box_size, para_r, para_m, para_T0, false, generate_z_flow(vz0));
# }
# ```
#
# ```shell
# root [0] .L nt.cpp
# root [1] cubic=default_z_flow()
# nσ^3 = 0.8
# (Cubic &) @0x7fa80b653000
# root [2] cubic.run(200,2e-8,false,true,1,false,true)
# Simulation[====================================================================================================] 100% [01m:27s<00m:00s] 200/200
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('particle_records_tensor.csv', header=None, names=['t', 'i', 'j', 'k', 'ux', 'uy', 'uz', 'pk_xx', 'pk_xy', 'pk_xz', 'pk_yx', 'pk_yy', 'pk_yz', 'pk_zx', 'pk_zy', 'pk_zz', 'qk_x', 'qk_y', 'qk_z'])
mean = data.groupby('t').mean()

# %%
data
# Out:
#                    t  i  j  k         ux         uy       uz         pk_xx  \
# 0       2.000000e-08  0  0  0  1767890.0 -2524520.0  3078.79  3.758070e+11
# 1       2.000000e-08  0  0  1  1389620.0 -1909250.0  3453.18  4.820680e+11
# 2       2.000000e-08  0  0  2   804795.0  2562330.0  3004.98  4.328950e+11
# 3       2.000000e-08  0  0  3  -436074.0   264916.0  3237.10  4.426390e+11
# 4       2.000000e-08  0  0  4 -2054850.0 -1279700.0  3224.30  4.728570e+11
# ...              ... .. .. ..        ...        ...      ...           ...
# 199995  4.000000e-06  9  9  5  1552820.0  2427080.0  2737.11  4.938990e+11
# 199996  4.000000e-06  9  9  6 -3010960.0 -1621740.0  3306.50  4.812330e+11
# 199997  4.000000e-06  9  9  7  -307312.0 -3038660.0  3199.29  4.387380e+11
# 199998  4.000000e-06  9  9  8 -2305740.0  2869330.0  3257.77  3.758310e+11
# 199999  4.000000e-06  9  9  9  3698460.0 -1968560.0  3102.06  3.063840e+11
#
#                pk_xy      pk_xz         pk_yx         pk_yy      pk_yz  \
# 0      -2.297690e+10 -2061060.0 -2.297690e+10  3.428810e+11  -469525.0
# 1       1.101360e+09  2144200.0  1.101360e+09  4.156280e+11 -6163230.0
# 2       4.763240e+10 -1976700.0  4.763240e+10  3.338100e+11  2696710.0
# 3      -3.707290e+10  4062070.0 -3.707290e+10  3.979550e+11 -3251230.0
# 4      -3.317160e+10  1764930.0 -3.317160e+10  3.838380e+11  1158300.0
# ...              ...        ...           ...           ...        ...
# 199995 -2.012820e+10 -2341290.0 -2.012820e+10  4.846020e+11  3115270.0
# 199996 -9.316390e+10  3070090.0 -9.316390e+10  4.921540e+11 -2568650.0
# 199997  9.444540e+10  4731610.0  9.444540e+10  4.671890e+11  -491475.0
# 199998 -8.086740e+10 -1665880.0 -8.086740e+10  4.105670e+11  1268830.0
# 199999 -1.072310e+10  2096780.0 -1.072310e+10  3.569050e+11   141569.0
#
#             pk_zx      pk_zy    pk_zz          qk_x          qk_y  \
# 0      -2061060.0  -469525.0  2847.12 -1.806540e+18 -1.814680e+18
# 1       2144200.0 -6163230.0  3478.86 -1.813250e+18 -2.643290e+18
# 2      -1976700.0  2696710.0  3708.59 -5.089320e+18 -5.015980e+17
# ...                    ...            ...           ...            ...
# 3.920000e-06  4.109676e+11  203171.084148 -76922.325580  203171.084148
# 3.940000e-06  4.109571e+11  184653.747200 -58381.792708  184653.747200
# 3.960000e-06  4.109372e+11  174833.385800 -75217.194596  174833.385800
# 3.980000e-06  4.109274e+11  157074.287150 -44527.138150  157074.287150
# 4.000000e-06  4.111860e+11  173894.423040 -17959.948260  173894.423040
#
#                    pk_zz          qk_x          qk_y          qk_z
# t
# 2.000000e-08  3419.48633  4.802026e+15  5.541719e+16  1.100241e+12
# 4.000000e-08  3419.15357 -2.813808e+16  3.748249e+16  1.482603e+12
# 6.000000e-08  3418.09462 -1.644707e+16  2.463343e+16  1.735760e+12
# 8.000000e-08  3420.08997  3.747598e+15  3.506525e+16  1.792072e+12
# 1.000000e-07  3420.59238  2.345543e+16  2.787092e+16  1.150694e+12
# ...                  ...           ...           ...           ...
# 3.920000e-06  3419.18671 -4.183083e+16  2.309660e+15  6.249453e+11
# 3.940000e-06  3418.45103 -3.544690e+16  2.056653e+15  6.631373e+11
# 3.960000e-06  3418.71210 -3.146208e+16 -5.086833e+14 -3.928997e+10
# 3.980000e-06  3419.88002 -2.340833e+16 -2.113149e+16 -2.559877e+11
# 4.000000e-06  3420.34351 -3.270099e+16 -2.410865e+16  2.030454e+11
#
# [200 rows x 18 columns]

# %%
fig, ax1 = plt.subplots()
ax1.plot(mean.index, mean['ux'], 'g', label='$u_x$')
ax1.plot(mean.index, mean['uy'], 'b', label='$u_y$')
ax2 = ax1.twinx()
ax2.plot(mean.index, mean['uz'], 'r', label='$u_z$')
ax1.legend(loc='upper left')
ax2.legend()

# %%
fig, ax1 = plt.subplots()
ax1.plot(mean.index, mean['pk_xz'], 'g', label='$p^k_{xz}$')
ax1.plot(mean.index, mean['pk_yz'], 'b', label='$p^k_{yz}$')
# ax1.plot(mean.index, mean['pk_zx'], label='$p^k_{zx}$')
# ax1.plot(mean.index, mean['pk_zy'], label='$p^k_{zy}$')
ax1.legend()
ax2 = ax1.twinx()
ax2.plot(mean.index, mean['pk_xy'], 'r', label='$p^k_{xy}$')
# ax2.plot(mean.index, mean['pk_yx'], label='$p^k_{yx}$')
ax2.legend()

# %%
fig, ax1 = plt.subplots()
ax1.plot(mean.index, mean['pk_xx'], 'g', label='$p^k_{xx}$')
ax1.plot(mean.index, mean['pk_yy'], 'b', label='$p^k_{yy}$')
ax1.legend(loc='upper left')
ax2 = ax1.twinx()
ax2.plot(mean.index, mean['pk_zz'], 'r', label='$p^k_{zz}$')
ax2.legend(loc='upper right')

# %%
fig, ax1 = plt.subplots()
ax1.plot(mean.index, mean['qk_x'], 'g', label='$q^k_x$')
ax1.plot(mean.index, mean['qk_y'], 'b', label='$q^k_y$')
ax2 = ax1.twinx()
ax2.plot(mean.index, mean['qk_z'], 'r', label='$q^k_z$')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# %%
Ts = pd.read_csv('particle_records_Ts.csv', header=None)
fig, ax1 = plt.subplots()
ax1.plot(Ts[0], Ts[1], label='$T$')
ax2 = ax1.twinx()
plt.xlabel('time (s)')
plt.ylabel('temperature (K)')
# linear regression using numpy
A = np.vstack([Ts[0], np.ones(len(Ts[0]))]).T
m, c = np.linalg.lstsq(A, Ts[1], rcond=None)[0]
ax2.plot(Ts[0], Ts[1]-m*Ts[0]-c, 'r', label='$T - T_{lin fit}$')
# plt.ylim(Ts[1].min(), Ts[1].max())
ax1.legend()
ax2.legend()
